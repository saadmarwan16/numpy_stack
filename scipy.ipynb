# %% [markdown]
# <a href="https://colab.research.google.com/github/saadmarwan16/numpy_stack/blob/main/scipy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
x = np.linspace(-6, 6, 1000)

# %%
fx = norm.pdf(x, loc=0, scale=1)

# %%
plt.plot(x, fx);

# %%
Fx = norm.cdf(x, loc=0, scale=1)

# %%
plt.plot(x, Fx);

# %%
logfx = norm.logpdf(x, loc=0, scale=1)
plt.plot(x, logfx);

# %%
logFx = norm.logcdf(x, loc=0, scale=1)
plt.plot(x, logFx);

# %%
# New section

# %%
from PIL import Image

# %%
# !wget https://cdn-nq.toyzzshop.com/product/600x600/33ba0_1:18_Bugatti_Chiron_Sport_Model_Araba.jpg
# Out:
# --2021-04-20 04:30:40--  https://cdn-nq.toyzzshop.com/product/600x600/33ba0_1:18_Bugatti_Chiron_Sport_Model_Araba.jpg
# Resolving cdn-nq.toyzzshop.com (cdn-nq.toyzzshop.com)... 176.53.6.148
# Connecting to cdn-nq.toyzzshop.com (cdn-nq.toyzzshop.com)|176.53.6.148|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20719 (20K) [image/jpeg]
# Saving to: ‘33ba0_1:18_Bugatti_Chiron_Sport_Model_Araba.jpg’
#
# 33ba0_1:18_Bugatti_ 100%[===================>]  20.23K  --.-KB/s    in 0.1s
#
# 2021-04-20 04:30:41 (179 KB/s) - ‘33ba0_1:18_Bugatti_Chiron_Sport_Model_Araba.jpg’ saved [20719/20719]

# %%
img = Image.open('2021-bugatti-chiron-super-sport-300.jpg')

# %%
gray = np.mean(img, axis=2)

# %%
x = np.linspace(-6, 6, 500)
fx = norm.pdf(x, loc=0, scale=1)

# %%
filt = np.outer(fx, fx)

# %%
plt.imshow(filt, cmap='gray');

# %%
from scipy.signal import convolve2d

# %%
out = convolve2d(gray, filt)

# %%
plt.subplot(1, 2, 1)
plt.imshow(gray, cmap='gray')
plt.subplot(1, 2, 2)
plt.imshow(out, cmap='gray');
